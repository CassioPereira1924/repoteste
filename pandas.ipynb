# %%
print('ola')
# Out:
# ola

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
dados = [
['Ana', 23, 'São Paulo'],
['Bruno', 35, 'Rio de Janeiro'],
['Carlos', 45, 'Belo Horizonte'],
['Daniela', 29, 'Curitiba']]

colunas = ['Nome','Idade', 'Cidade']

df = pd.DataFrame(dados, columns= colunas)

# %%
df
# Out:
#       Nome  Idade          Cidade
# 0      Ana     23       São Paulo
# 1    Bruno     35  Rio de Janeiro
# 2   Carlos     45  Belo Horizonte
# 3  Daniela     29        Curitiba

# %%
dict = {
'Nome': ['Eduardo', 'Fernanda', 'Gabriel', 'Helena'],
'Idade': [32, 27, 41, 36],
'Cidade': ['Porto Alegre', 'Salvador', 'Fortaleza', 'Recife']
}

df = pd.DataFrame(dict)
df
# Out:
#        Nome  Idade        Cidade
# 0   Eduardo     32  Porto Alegre
# 1  Fernanda     27      Salvador
# 2   Gabriel     41     Fortaleza
# 3    Helena     36        Recife

# %%
df = pd.read_csv('2º_2024.csv', sep= ';')
df.head(5)
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio                   Revenda  \
# 0              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 1              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 2              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 3              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 4              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
#
#        CNPJ da Revenda                                        Nome da Rua  \
# 0   08.220.930/0001-62  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...
# 1   08.220.930/0001-62  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...
# 2   08.220.930/0001-62  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...
# 3   08.220.930/0001-62  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...
# 4   08.220.930/0001-62  RODOVIA BR-364 (RIO BRANCO-CRUZEIRO DO SUL) - ...
#
#   Numero Rua                Complemento              Bairro        Cep  \
# ...

# %%
df['Valor de Venda'] = df['Valor de Venda'].str.replace(',','.').astype(float)
print(df['Valor de Venda'].dtype)
# Out:
# float64

# %%
df.tail(5)
# Out:
#        Regiao - Sigla Estado - Sigla Municipio  \
# 421377             CO             GO   FORMOSA
# 421378             CO             GO   FORMOSA
# 421379             CO             GO   FORMOSA
# 421380             CO             GO   FORMOSA
# 421381             CO             GO   FORMOSA
#
#                                                   Revenda  \
# 421377  PARANA DE FORA COMERCIO DE COMBUSTIVEIS E LUBR...
# 421378  PARANA DE FORA COMERCIO DE COMBUSTIVEIS E LUBR...
# 421379  PARANA DE FORA COMERCIO DE COMBUSTIVEIS E LUBR...
# 421380  PARANA DE FORA COMERCIO DE COMBUSTIVEIS E LUBR...
# 421381  PARANA DE FORA COMERCIO DE COMBUSTIVEIS E LUBR...
#
#             CNPJ da Revenda Nome da Rua Numero Rua  \
# 421377   48.113.920/0001-42   AVENIDA A         SN
# 421378   48.113.920/0001-42   AVENIDA A         SN
# 421379   48.113.920/0001-42   AVENIDA A         SN
# 421380   48.113.920/0001-42   AVENIDA A         SN
# 421381   48.113.920/0001-42   AVENIDA A         SN
#
# ...

# %%
df.info() # Informações gerais
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421382 entries, 0 to 421381
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     421382 non-null  object
#  1   Estado - Sigla     421382 non-null  object
#  2   Municipio          421382 non-null  object
#  3   Revenda            421382 non-null  object
#  4   CNPJ da Revenda    421382 non-null  object
#  5   Nome da Rua        421382 non-null  object
#  6   Numero Rua         421282 non-null  object
#  7   Complemento        94698 non-null   object
#  8   Bairro             420809 non-null  object
#  9   Cep                421382 non-null  object
#  10  Produto            421382 non-null  object
#  11  Data da Coleta     421382 non-null  object
#  12  Valor de Venda     421382 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  421382 non-null  object
# ...

# %%
print(df['Valor de Venda'].dtype)
# Out:
# object

# %%
df.describe() # Estatísticas descritivas
# Out:
#        Valor de Venda  Valor de Compra
# count   421382.000000              0.0
# mean         5.684103              NaN
# std          0.888075              NaN
# min          2.990000              NaN
# 25%          5.480000              NaN
# 50%          5.970000              NaN
# 75%          6.260000              NaN
# max          9.790000              NaN

# %%
df.shape # Dimensões (linhas, colunas)
# Out:
# (421382, 16)

# %%
df.columns # Lista de coluna
# Out:
# Index(['Regiao - Sigla', 'Estado - Sigla', 'Municipio', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Numero Rua', 'Complemento', 'Bairro',
#        'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 'Valor de Compra',
#        'Unidade de Medida', 'Bandeira'],
#       dtype='object')

# %%
df.iloc[10:15] # Acesso por índice
# Out:
#    Regiao - Sigla Estado - Sigla   Municipio                    Revenda  \
# 10              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 11              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 12              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 13              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 14              N             AC  RIO BRANCO     AUTO POSTO ACAUAN LTDA
#
#         CNPJ da Revenda       Nome da Rua Numero Rua Complemento     Bairro  \
# 10   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN      AREAL
# 11   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN      AREAL
# 12   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN      AREAL
# 13   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN      AREAL
# 14   00.524.999/0001-78     RODOVIA AC 40       1800         NaN  VILA ACRE
#
#           Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
df_RJ = df.loc[(df['Estado - Sigla'] == 'RJ') & (df['Bairro'] == 'PAVUNA')] # Acesso por condição
#df_RJ = df.loc[df['Estado - Sigla'] == 'RJ']
df_RJ.head()
# Out:
#       Regiao - Sigla Estado - Sigla       Municipio  \
# 87774             SE             RJ  RIO DE JANEIRO
# 87775             SE             RJ  RIO DE JANEIRO
# 87776             SE             RJ  RIO DE JANEIRO
# 87777             SE             RJ  RIO DE JANEIRO
# 87778             SE             RJ  RIO DE JANEIRO
#
#                                 Revenda      CNPJ da Revenda  \
# 87774  POSTO SANTA CLARA DA PAVUNA LTDA   03.246.347/0001-07
# 87775  POSTO SANTA CLARA DA PAVUNA LTDA   03.246.347/0001-07
# 87776  POSTO SANTA CLARA DA PAVUNA LTDA   03.246.347/0001-07
# 87777  POSTO SANTA CLARA DA PAVUNA LTDA   03.246.347/0001-07
# 87778  POSTO SANTA CLARA DA PAVUNA LTDA   03.246.347/0001-07
#
#                                  Nome da Rua Numero Rua Complemento  Bairro  \
# 87774  AVENIDA PROFESSOR BERNARDINO DA ROCHA        113         NaN  PAVUNA
# 87775  AVENIDA PROFESSOR BERNARDINO DA ROCHA        113         NaN  PAVUNA
# ...

# %%
dados = {
'Departamento': ['Vendas', 'Vendas', 'RH', 'RH', 'TI', 'TI'],
'Funcionário': ['Ana', 'Bruno', 'Carlos', 'Daniela', 'Eduardo', 'Fernanda'],
'Salário': [3000, 3200, 2500, 2700, 4000, 4200]
}
df = pd.DataFrame(dados)
df
# Out:
#   Departamento Funcionário  Salário
# 0       Vendas         Ana     3000
# 1       Vendas       Bruno     3200
# 2           RH      Carlos     2500
# 3           RH     Daniela     2700
# 4           TI     Eduardo     4000
# 5           TI    Fernanda     4200

# %%
#df.groupby('Departamento').mean(numeric_only=True)
df_departamento = df.groupby('Departamento')['Salário'].mean().reset_index()
df_departamento
# Out:
#   Departamento  Salário
# 0           RH   2600.0
# 1           TI   4100.0
# 2       Vendas   3100.0

# %%
caramelo_rj = caramelo.loc[caramelo['Estado Loja'] == 'RJ']
caramelo_cidades = caramelo_rj.groupby('Cidade Loja')['Valor de Venda'].sum().reset_index()
caramelo_cidades = caramelo_cidades.sort_values(by='Valor de Venda', ascending= False)
caramelo_cidades

# %%
caramelo_cidades.plot(kind='bar',  x='Cidade Loja', y='Valor de Venda')
plt.xlabel('Cidade')
plt.ylabel('Preço Médio')
plt.title('Preço Médio por Cidade')
plt.show()
