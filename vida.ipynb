# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dados_saude_estilo_vida.csv')
df
# Out:
#      Atividade Física (min/dia)    IMC  Consumo de Frutas (porções/dia)  \
# 0                          35.0  13.92                              2.0
# 1                          29.0  16.62                              3.0
# 2                          36.0  11.82                              2.0
# 3                          45.0   6.74                              3.0
# 4                          28.0  16.87                              1.0
# ..                          ...    ...                              ...
# 995                        27.0  17.48                              3.0
# 996                        48.0   5.99                              3.0
# 997                        36.0  10.91                              2.0
# 998                        24.0  17.69                              3.0
# 999                        36.0  11.39                              3.0
#
#      Nível de Estresse  Consumo Calórico (kcal/dia)  Horas de Sono  \
# ...

# %%
plt.scatter(df['Atividade Física (min/dia)'],df['IMC'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['Horas de Sono'], df['Nível de Estresse'])

# %%
plt.scatter(df['Consumo de Frutas (porções/dia)'], df['Consumo Calórico (kcal/dia)'])
